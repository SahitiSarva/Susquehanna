# %%
import geopandas as gpd

# %%
import matplotlib.pylab as plt
import shapefile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-163c1a468891> in <module>
#       1 import matplotlib.pylab as plt
# ----> 2 import shapefile
#
# ModuleNotFoundError: No module named 'shapefile'

# %%
lower_susquehanna_basin = gpd.read_file('.\mygeodata\SRBCLowerSusquehannaSubbasin-polygon.shp')

# %%
lower_susquehanna_basin.plot()
# Out:
# <AxesSubplot:>

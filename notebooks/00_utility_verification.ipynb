# %%
# %reload_ext autoreload
# %autoreload 2
from utilities import *
from visuals import *

# %%
payoffs = load_data("../model/data/processed/50yr_all2.pickle")

# %%
plot_outcome_utility(payoffs = payoffs, label = 'compare utilities')

# %%
get_marginal_utility(-3.5)
# Out:
# -16.108147292244144

# %%
plot_outcome_utility(get_marginal_utility_of_df, payoffs, 'diminishing utility')

# %%
get_all_fairness_metrics(payoffs, get_marginal_utility_of_df, rho =0, gamma =0)
# Out:
#            gini_index     utility  hydropower_revenue  \
# decision
# policy1      0.200221  104.990859           64.637100
# policy2      0.412775  104.022696           64.294681
# policy3      0.238979  104.826251           64.433695
# policy4      0.159529  104.071320           64.686542
# policy5      0.170738  104.876087           64.691368
# ...               ...         ...                 ...
# policy103    0.316976  103.368402           65.060494
# policy104    0.344164  103.322403           64.432018
# policy105    0.247437  104.601492           64.365801
# policy106    0.269928  104.732693           64.401442
# policy107    0.251865  104.365591           64.760593
#
#            atomic_power_plant_discharge  baltimore_discharge  \
# decision
# policy1                       20.674487            20.406530
# policy2                       20.674678            20.576598
# policy3                       20.675034            20.311214
# ...

# %%
plot_gamma_values(get_all_fairness_metrics, payoffs, get_marginal_utility_of_df, rho =0)

# %%
df = get_all_fairness_metrics(payoffs, get_marginal_utility_of_df, gamma = 1, rho = 2)[['utility', 'prioritarian_welfare']]
df
sns.scatterplot(df['utility'], df['prioritarian_welfare'])
# Out:
# C:\Users\sahit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='utility', ylabel='prioritarian_welfare'>

# %%
utilities = get_marginal_utility_of_df(payoffs, rho =0)
utilities[utilities.index == 'policy13']
# Out:
#           hydropower_revenue  atomic_power_plant_discharge  \
# decision
# policy13           65.390738                     20.674462
#
#           baltimore_discharge  chester_discharge  recreation  environment  \
# decision
# policy13               20.101          20.597232   20.785714    -20.28185
#
#           flood_risk
# decision
# policy13  -23.463494

# %%
df[(df['utility']>183.5) & (df['utility']<184) & (df['prioritarian_welfare']>22.04) & (df['prioritarian_welfare']<22.06)]
# Out:
# Empty DataFrame
# Columns: [utility, prioritarian_welfare]
# Index: []

# %%
df = get_prioritarian_swf_for_df(payoffs, get_marginal_utility_of_df, gamma = 1, rho =0)
df = df.sort_values(by = 'prioritarian_welfare')
df.plot()
# Out:
# <AxesSubplot:xlabel='decision'>

# %%
plot_gamma_values(get_all_fairness_metrics, payoffs, get_marginal_utility_of_df, rho =0)
